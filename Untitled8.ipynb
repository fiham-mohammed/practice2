# %% [markdown]
# <a href="https://colab.research.google.com/github/fiham-mohammed/practice2/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploratory Data Analysis (EDA)
# ## AI-Driven Coronary Disease Detection and Decision Support System
# ### Patient Recommendation System

# %% [markdown]
# Import Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# Load the Dataset

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/DSGP/Heart_health new.csv")

# %% [markdown]
# Dataset Overview

# %%
df.head()

#Dataset Shape
df.shape
# Out:
# (724, 12)

# %% [markdown]
# Data Types & Structure

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 724 entries, 0 to 723
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   724 non-null    int64
#  1   Name                 724 non-null    object
#  2   Age                  724 non-null    int64
#  3   Gender               724 non-null    object
#  4   Height cm            724 non-null    int64
#  5   Weight kg            724 non-null    int64
#  6   Blood Pressure mmHg  724 non-null    object
#  7   Cholesterol mg/dL    724 non-null    int64
#  8   Glucose mg/dL        724 non-null    int64
#  9   Smoker               724 non-null    object
#  10  Exercise hours/week  724 non-null    int64
#  11  Heart Attack         724 non-null    int64
# dtypes: int64(8), object(4)
# memory usage: 68.0+ KB

# %% [markdown]
# Statistical Summary

# %%
df.describe()
# Out:
#                ID         Age   Height cm   Weight kg  Cholesterol mg/dL  \
# count  724.000000  724.000000  724.000000  724.000000         724.000000
# mean   361.712707   44.842541  171.161602   75.610497         206.022099
# std    207.901609    8.162429    6.242018    6.368595          11.224704
# min      1.000000   30.000000  155.000000   60.000000         170.000000
# 25%    181.750000   38.000000  166.000000   71.000000         195.000000
# 50%    362.500000   44.000000  170.000000   75.000000         210.000000
# 75%    543.250000   53.000000  177.000000   81.000000         215.000000
# max    714.000000   60.000000  183.000000   89.000000         230.000000
#
#        Glucose mg/dL  Exercise hours/week  Heart Attack
# count     724.000000           724.000000    724.000000
# mean       92.179558             2.770718      0.599448
# std         4.662712             0.934907      0.490349
# min        75.000000             1.000000      0.000000
# ...

# %% [markdown]
# Missing Value Analysis

# %%
df.isnull().sum()
# Out:
# ID                     0
# Name                   0
# Age                    0
# Gender                 0
# Height cm              0
# Weight kg              0
# Blood Pressure mmHg    0
# Cholesterol mg/dL      0
# Glucose mg/dL          0
# Smoker                 0
# Exercise hours/week    0
# Heart Attack           0
# dtype: int64

# %% [markdown]
# Target Variable Analysis (Heart Attack)

# %%
df['Heart Attack'].value_counts()
df['Heart Attack'].value_counts(normalize=True)
sns.countplot(x='Heart Attack', data=df)
plt.title("Heart Attack Class Distribution")
plt.show()

# %% [markdown]
# Univariate Analysis (Numerical Features)

# %%
#Age Distribution
plt.hist(df['Age'], bins=20)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

#Cholesterol Distribution
plt.hist(df['Cholesterol mg/dL'], bins=20)
plt.title("Cholesterol Distribution")
plt.xlabel("Cholesterol (mg/dL)")
plt.ylabel("Frequency")
plt.show()

#Exercise Hours per Week
plt.hist(df['Exercise hours/week'], bins=20)
plt.title("Exercise Hours per Week")
plt.xlabel("Hours")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Categorical Feature Analysis

# %%
#Gender Distribution
df['Gender'].value_counts()

sns.countplot(x='Gender', data=df)
plt.title("Gender Distribution")
plt.show()


#Smoking Status
df['Smoker'].value_counts()

sns.countplot(x='Smoker', data=df)
plt.title("Smoking Status Distribution")
plt.show()

# %% [markdown]
# Bivariate Analysis (Feature vs Target)

# %%
#Age vs Heart Attack
sns.boxplot(x='Heart Attack', y='Age', data=df)
plt.title("Age vs Heart Attack")
plt.show()

#Cholesterol vs Heart Attack
sns.boxplot(x='Heart Attack', y='Cholesterol mg/dL', data=df)
plt.title("Cholesterol vs Heart Attack")
plt.show()

#Exercise vs Heart Attack
sns.boxplot(x='Heart Attack', y='Exercise hours/week', data=df)
plt.title("Exercise Hours vs Heart Attack")
plt.show()

# %% [markdown]
# Blood Pressure Feature Analysis

# %%
#Split Blood Pressure into Systolic & Diastolic
df[['Systolic_BP', 'Diastolic_BP']] = df['Blood Pressure mmHg'] \
    .str.split('/', expand=True).astype(int)

df[['Systolic_BP', 'Diastolic_BP']].describe()
# Out:
#        Systolic_BP  Diastolic_BP
# count   724.000000    724.000000
# mean    121.662983     77.541436
# std       4.000306      3.095474
# min     105.000000     65.000000
# 25%     119.000000     75.000000
# 50%     122.000000     78.000000
# 75%     125.000000     80.000000
# max     135.000000     85.000000

# %% [markdown]
# Correlation Analysis

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()
